# %%
# Hounds and Hare Game

# %% [markdown]
# # Import packages

# %%
# !pip install matplotlib networkx -q
# !pip install gym -q

# %%
from hounds_and_hare import HoundsAndHare
from hounds_and_hare_env import HoundsAndHareEnv
import gym
from gym.envs.registration import register

# %% [markdown]
# # Testing board display and moves

# %%
# Example usage
game = HoundsAndHare()

# %%
game.display_board()
# Out:
# H H . .
# . . .
# H . . R

# %%
game.visualize_board()

# %%
print(game.move_hound(1, 5))
print(game.move_hound(7, 9))
# Out:
# True
# False

# %%
print(game.move_hare(6))
print(game.move_hare(8))
# Out:
# True
# False

# %%
game.visualize_board()

# %% [markdown]
# # Register and Create the Environment

# %%
register(
    id='HoundsAndHareEnv-v0',
    entry_point='hounds_and_hare_env:HoundsAndHareEnv',
)

# %%
env = gym.make('HoundsAndHareEnv-v0')

# %% [markdown]
# # Test the environment

# %%
for episode in range(3):  # Run 5 test episodes
    state = env.reset()
    done = False
    step_count = 0
    
    print(f"Episode {episode + 1}")
    
    while not done and step_count < 5:  # Limit steps to avoid infinite loops
        action = env.action_space.sample()  # Random action
        next_state, reward, done, _ = env.step(action)
        
        print(f"Step {step_count}: Action {action} -> Reward: {reward}, Done: {done}")
        env.render()  # Visualize the game state
        state = next_state
        step_count += 1
    
    print("Episode finished/n")

env.close()
# Out:
# Episode 1
# Step 0: Action 40 -> Reward: 0, Done: False
# Step 1: Action 29 -> Reward: 0, Done: False
# Step 2: Action 34 -> Reward: 0, Done: False
# Step 3: Action 8 -> Reward: 0, Done: False
# Step 4: Action 23 -> Reward: 0, Done: False
# Episode finished/n
# Episode 2
# Step 0: Action 5 -> Reward: 0, Done: False
# Step 1: Action 29 -> Reward: 0, Done: False
# Step 2: Action 11 -> Reward: 0, Done: False
# Step 3: Action 6 -> Reward: 0, Done: False
# Step 4: Action 36 -> Reward: 0, Done: False
# Episode finished/n
# Episode 3
# Step 0: Action 4 -> Reward: 0, Done: False
# Step 1: Action 23 -> Reward: 0, Done: False
# Step 2: Action 9 -> Reward: 0, Done: False
# Step 3: Action 7 -> Reward: 0, Done: False
# Step 4: Action 37 -> Reward: 0, Done: False
# Episode finished/n
